# %%
print("Hello,exited to start data science." )
# Out:
# Hello,exited to start data science.

# %%
customer_name="Jhon"
customer_age="28"
customer_balance="120.70"
print("customer:",customer_name)
print("Age:",customer_age)
print("Balance:",customer_balance)
# Out:
# customer: Jhon
# Age: 28
# Balance: 120.70

# %%
from typing_extensions import final
product_price=200
discount=product_price*0.10
final_price=product_price-discount
print("Final price after discount ",final_price)
# Out:
# Final price after discount  180.0

# %%
import numpy as np
sales=np.array([150,200,250,300,400,350,500])
print("Sales Data:",sales)
# Out:
# Sales Data: [150 200 250 300 400 350 500]

# %%
import numpy as np
sales=np.array([150,200,250,300,400,350,500])
print("Average Sales:",np.mean(sales))
print("Highest sale:",np.max(sales))
print("Lowest sale:",np.min(sales))
# Out:
# Average Sales: 307.14285714285717
# Highest sale: 500
# Lowest sale: 150

# %%
import pandas as pd
data={
    "Custemer":["Alice","Bob","Charlie"],
    "Age":[25,30,35],
    "Amount spend":[120,200,150]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Custemer  Age  Amount spend
# 0    Alice   25           120
# 1      Bob   30           200
# 2  Charlie   35           150

# %%
from google.colab import files
uploaded=files.upload()
df=pd.read_csv("customer_data.csv")
df.head()
# Out:
#      <input type="file" id="files-f0221f26-dd62-472c-8d9c-bdf629571cdf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0221f26-dd62-472c-8d9c-bdf629571cdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data={
    "Custemer":["Alice","Bob","Charlie"],
    "Age":[25,30,35],
    "Amount spend":[120,200,150]
}
df=pd.DataFrame(data)
print(df)
high_spenders=df[df["Amount spend"]>150]
print(high_spenders)
# Out:
#   Custemer  Age  Amount spend
# 0    Alice   25           120
# 1      Bob   30           200
# 2  Charlie   35           150
#   Custemer  Age  Amount spend
# 1      Bob   30           200

# %%
import pandas as pd
data={
    "Custemer":["Alice","Bob","Charlie"],
    "Age":[25,30,35],
    "Amount spend":[120,200,150]
}
df=pd.DataFrame(data)
df_sorted=df.sort_values(by="Amount spend",ascending=False)
print(df_sorted)
# Out:
#   Custemer  Age  Amount spend
# 1      Bob   30           200
# 2  Charlie   35           150
# 0    Alice   25           120

# %%
import pandas as pd
data={
    "Custemer":["Alice","Bob","Charlie"],
    "Age":[25,30,35],
    "Amount spend":[120,200,150]
}
df=pd.DataFrame(data)
df["Loyalty points"]=df["Amount spend"]//10
print(df)
# Out:
#   Custemer  Age  Amount spend  Loyalty points
# 0    Alice   25           120              12
# 1      Bob   30           200              20
# 2  Charlie   35           150              15

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
df=pd.read_csv("customer_data.csv")
df.head()
df.to_csv("cleaned_customer_data.csv", index=False)
files.download("cleaned_customer_data.csv")
# Out:
#      <input type="file" id="files-3974905d-96c4-45dd-8395-59fb0f3da2c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3974905d-96c4-45dd-8395-59fb0f3da2c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
